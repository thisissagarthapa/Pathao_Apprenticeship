# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r'C:\Users\HP\Desktop\pathao\users.csv')

# %%
dataset.head()
# Out:
#    1       Diwash Ale      diwas.ale@pathao.com  null  \
# 0  2   Nandu Acharaya  nanda.acharya@pathao.com   NaN
# 1  3     Kendra Regmi   kendra.regmi@pathao.com   NaN
# 2  4      Ajaya Limbu          ajaya@pathao.com   NaN
# 3  5  Mahima Kalikote         mahima@pathao.com   NaN
# 4  6      Sagar Magar    sagar.magar@pathao.com   NaN
#
#   $2y$10$Ak3Sq4ZcPZO9wwKfvpHv/ePFQ9oyYugEBoG3b0kbBQFvfzgU/ZM9m  null.1  \
# 0  $2y$10$Z0yt.rVs3CaSJuncPtxUAuECePoSGeegLNzW6mu...               NaN
# 1  $2y$10$U.b2x9Lq7RJQLzkr3Fuf5e2Ep4brGFUT.Fh.FqB...               NaN
# 2  $2y$10$8WLQkS.jmITlfkT/w/vEdOWlZXSgPZ4JqdcID4n...               NaN
# 3  $2y$10$dCAKfP.PGLyjpN5wMP.8eumKMtOY2pn07lqPKyI...               NaN
# 4  $2y$10$9YBiSV9pPnKyjXkG35cRCOw1gHypRTReFdj5V.N...               NaN
#
#    2024-01-23 04:28:34  2024-01-23 10:15:05  \
# 0  2024-01-23 10:16:45  2024-01-23 18:46:14
# 1  2024-01-23 10:25:41  2024-01-23 10:26:38
# 2  2024-01-23 11:56:16  2024-01-23 11:56:16
# ...

# %%
dataset.isnull()
# Out:
#         1  Diwash Ale  diwas.ale@pathao.com  null  \
# 0   False       False                 False  True
# 1   False       False                 False  True
# 2   False       False                 False  True
# 3   False       False                 False  True
# 4   False       False                 False  True
# 5   False       False                 False  True
# 6   False       False                 False  True
# 7   False       False                 False  True
# 8   False       False                 False  True
# 9   False       False                 False  True
# 10  False       False                 False  True
# 11  False       False                 False  True
# 12  False       False                 False  True
# 13  False       False                 False  True
#
#     $2y$10$Ak3Sq4ZcPZO9wwKfvpHv/ePFQ9oyYugEBoG3b0kbBQFvfzgU/ZM9m  null.1  \
# 0                                               False               True
# ...

# %%
dataset.isnull().sum()
# Out:
# 1                                                                0
# Diwash Ale                                                       0
# diwas.ale@pathao.com                                             0
# null                                                            14
# $2y$10$Ak3Sq4ZcPZO9wwKfvpHv/ePFQ9oyYugEBoG3b0kbBQFvfzgU/ZM9m     0
# null.1                                                          14
# 2024-01-23 04:28:34                                              0
# 2024-01-23 10:15:05                                              0
# profile/tG9vjs4qUtWiDJuu7gAxgMOpVti6i1oe0IM9Q267.jpg            12
# dtype: int64

# %%
dataset.drop(columns=["null","null.1"],inplace=True)

# %%
dataset.isnull().sum()
# Out:
# 1                                                                0
# Diwash Ale                                                       0
# diwas.ale@pathao.com                                             0
# $2y$10$Ak3Sq4ZcPZO9wwKfvpHv/ePFQ9oyYugEBoG3b0kbBQFvfzgU/ZM9m     0
# 2024-01-23 04:28:34                                              0
# 2024-01-23 10:15:05                                              0
# profile/tG9vjs4qUtWiDJuu7gAxgMOpVti6i1oe0IM9Q267.jpg            12
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.isnull().sum().sum()
# Out:
# 12

# %%
dataset[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dataset[0]
#
# ...

# %%
dataset["profile/tG9vjs4qUtWiDJuu7gAxgMOpVti6i1oe0IM9Q267.jpg"]
# Out:
# 0     profile/SrVxywZEcODMdL4r1sjekFsRgv5bXIPnwQfVdS...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8     profile/8cpMD8hdmbKYgY7hmRBvyuRNcL9vjTEuXKg0Dv...
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# Name: profile/tG9vjs4qUtWiDJuu7gAxgMOpVti6i1oe0IM9Q267.jpg, dtype: object

# %%
dataset["profile/tG9vjs4qUtWiDJuu7gAxgMOpVti6i1oe0IM9Q267.jpg"]="Images"

# %%
print(dataset.columns)
# Out:
# Index(['1', 'Diwash Ale', 'diwas.ale@pathao.com',
#        '$2y$10$Ak3Sq4ZcPZO9wwKfvpHv/ePFQ9oyYugEBoG3b0kbBQFvfzgU/ZM9m',
#        '2024-01-23 04:28:34', '2024-01-23 10:15:05',
#        'profile/tG9vjs4qUtWiDJuu7gAxgMOpVti6i1oe0IM9Q267.jpg'],
#       dtype='object')

# %%
dataset.rename(columns={"profile/tG9vjs4qUtWiDJuu7gAxgMOpVti6i1oe0IM9Q267.jpg":"Images"},inplace=True)

# %%
dataset.head()
# Out:
#    1       Diwash Ale      diwas.ale@pathao.com  \
# 0  2   Nandu Acharaya  nanda.acharya@pathao.com
# 1  3     Kendra Regmi   kendra.regmi@pathao.com
# 2  4      Ajaya Limbu          ajaya@pathao.com
# 3  5  Mahima Kalikote         mahima@pathao.com
# 4  6      Sagar Magar    sagar.magar@pathao.com
#
#   $2y$10$Ak3Sq4ZcPZO9wwKfvpHv/ePFQ9oyYugEBoG3b0kbBQFvfzgU/ZM9m  \
# 0  $2y$10$Z0yt.rVs3CaSJuncPtxUAuECePoSGeegLNzW6mu...
# 1  $2y$10$U.b2x9Lq7RJQLzkr3Fuf5e2Ep4brGFUT.Fh.FqB...
# 2  $2y$10$8WLQkS.jmITlfkT/w/vEdOWlZXSgPZ4JqdcID4n...
# 3  $2y$10$dCAKfP.PGLyjpN5wMP.8eumKMtOY2pn07lqPKyI...
# 4  $2y$10$9YBiSV9pPnKyjXkG35cRCOw1gHypRTReFdj5V.N...
#
#    2024-01-23 04:28:34  2024-01-23 10:15:05  Images
# 0  2024-01-23 10:16:45  2024-01-23 18:46:14  Images
# 1  2024-01-23 10:25:41  2024-01-23 10:26:38  Images
# 2  2024-01-23 11:56:16  2024-01-23 11:56:16  Images
# 3  2024-01-23 18:38:05  2024-01-23 18:38:05  Images
# 4  2024-01-23 18:39:14  2024-01-23 18:39:14  Images

# %%
dataset.isnull().sum()
# Out:
# 1                                                               0
# Diwash Ale                                                      0
# diwas.ale@pathao.com                                            0
# $2y$10$Ak3Sq4ZcPZO9wwKfvpHv/ePFQ9oyYugEBoG3b0kbBQFvfzgU/ZM9m    0
# 2024-01-23 04:28:34                                             0
# 2024-01-23 10:15:05                                             0
# Images                                                          0
# dtype: int64

# %%
dataset['Images']="images/batman.jpg"

# %%
dataset.head()
# Out:
#    1       Diwash Ale      diwas.ale@pathao.com  \
# 0  2   Nandu Acharaya  nanda.acharya@pathao.com
# 1  3     Kendra Regmi   kendra.regmi@pathao.com
# 2  4      Ajaya Limbu          ajaya@pathao.com
# 3  5  Mahima Kalikote         mahima@pathao.com
# 4  6      Sagar Magar    sagar.magar@pathao.com
#
#   $2y$10$Ak3Sq4ZcPZO9wwKfvpHv/ePFQ9oyYugEBoG3b0kbBQFvfzgU/ZM9m  \
# 0  $2y$10$Z0yt.rVs3CaSJuncPtxUAuECePoSGeegLNzW6mu...
# 1  $2y$10$U.b2x9Lq7RJQLzkr3Fuf5e2Ep4brGFUT.Fh.FqB...
# 2  $2y$10$8WLQkS.jmITlfkT/w/vEdOWlZXSgPZ4JqdcID4n...
# 3  $2y$10$dCAKfP.PGLyjpN5wMP.8eumKMtOY2pn07lqPKyI...
# 4  $2y$10$9YBiSV9pPnKyjXkG35cRCOw1gHypRTReFdj5V.N...
#
#    2024-01-23 04:28:34  2024-01-23 10:15:05             Images
# 0  2024-01-23 10:16:45  2024-01-23 18:46:14  images/batman.jpg
# 1  2024-01-23 10:25:41  2024-01-23 10:26:38  images/batman.jpg
# 2  2024-01-23 11:56:16  2024-01-23 11:56:16  images/batman.jpg
# 3  2024-01-23 18:38:05  2024-01-23 18:38:05  images/batman.jpg
# ...
